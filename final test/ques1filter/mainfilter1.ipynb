# %%
import cv2
import numpy as np
from matplotlib  import pyplot as plt

# %%
img=cv2.imread("blur.png")
ker= np.array(
    [
        [0,-1,0],
        [-1,5,-1],
        [0,-1,0]

    ]
)
dst1 = cv2.filter2D(img,-1,ker)
plt.imshow(dst1[:,:,::-1])
